# %% [markdown]
# # Lecture 2: Gym

# %% [markdown]
# **Dependencies and setup** (this can take a minute or so...)

# %%
# !pip install ipykernel
# !pip install swig

# !pip install rldurham  # latest release
# !pip install git+https://github.com/robert-lieck/rldurham.git@main  # latest main version (typically same as release)
# !pip install git+https://github.com/robert-lieck/rldurham.git@dev  # latest dev version
# Out:
# Requirement already satisfied: ipykernel in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (7.1.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (26.0)
# Requirement already satisfied: psutil>=5.7 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/ameliemajor/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Collecting swig
#   Downloading swig-4.4.1-py3-none-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Downloading swig-4.4.1-py3-none-macosx_10_9_universal2.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 4.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Collecting rldurham
#   Downloading rldurham-0.1.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: IPython in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham) (9.9.0)
# Collecting ipywidgets (from rldurham)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting requests (from rldurham)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting gymnasium[Box2D,atari,other] (from rldurham)
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting torch (from rldurham)
#   Using cached torch-2.10.0-cp311-none-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting numpy (from rldurham)
#   Using cached numpy-2.4.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting scipy (from rldurham)
#   Using cached scipy-1.17.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pandas (from rldurham)
#   Using cached pandas-3.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting lightning (from rldurham)
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium[Box2D,atari,other]->rldurham)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ameliemajor/.local/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting ale_py>=0.9 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading ale_py-0.11.2-cp311-cp311-macosx_13_0_arm64.whl.metadata (9.0 kB)
# Collecting box2d==2.3.10 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading Box2D-2.3.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (573 bytes)
# Collecting pygame>=2.1.3 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading pygame-2.6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: swig==4.* in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham) (4.4.1)
# Collecting moviepy>=1.0.0 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting matplotlib>=3.0 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting opencv-python>=3.0 (from gymnasium[Box2D,atari,other]->rldurham)
#   Downloading opencv_python-4.13.0.90-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting seaborn>=0.13 (from gymnasium[Box2D,atari,other]->rldurham)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (26.0)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Using cached pillow-12.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham) (5.2.1)
# Collecting imageio<3.0,>=2.5 (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham)
#   Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting tqdm (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six>=1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham) (1.17.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->rldurham) (0.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jedi>=0.18.1->IPython->rldurham) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from pexpect>4.3->IPython->rldurham) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham) (0.2.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham) (0.2.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->rldurham)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->rldurham)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Collecting PyYAML<8.0,>5.4 (from lightning->rldurham)
#   Using cached pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting fsspec<2027.0,>=2022.5.0 (from fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->rldurham)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning->rldurham)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting pytorch-lightning (from lightning->rldurham)
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Downloading aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: setuptools in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->rldurham) (80.9.0)
# Collecting filelock (from torch->rldurham)
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting sympy>=1.13.3 (from torch->rldurham)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->rldurham)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch->rldurham)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached yarl-1.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (75 kB)
# Collecting idna>=2.0 (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->rldurham)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->rldurham)
#   Using cached markupsafe-3.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->rldurham)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->rldurham)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests->rldurham)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading rldurham-0.1.1-py3-none-any.whl (31 kB)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 14.0 MB/s  0:00:00
# Downloading Box2D-2.3.10-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.8 MB/s  0:00:00
# Downloading ale_py-0.11.2-cp311-cp311-macosx_13_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 13.5 MB/s  0:00:00
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 16.8 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 17.0 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 12.3 MB/s  0:00:00 eta 0:00:01
# Downloading proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 12.7 MB/s  0:00:01m0:00:0100:01
# Using cached numpy-2.4.1-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# Downloading opencv_python-4.13.0.90-cp37-abi3-macosx_13_0_arm64.whl (46.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 7.1 MB/s  0:00:06 eta 0:00:01
# Downloading pygame-2.6.1-cp311-cp311-macosx_11_0_arm64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 17.0 MB/s  0:00:00 eta 0:00:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached pandas-3.0.0-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 13.9 MB/s  0:00:00
# Using cached fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Using cached pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Using cached torch-2.10.0-cp311-none-macosx_11_0_arm64.whl (79.4 MB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 17.0 MB/s  0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl (494 kB)
# Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Using cached yarl-1.22.0-cp311-cp311-macosx_11_0_arm64.whl (94 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.20.3-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 15.1 MB/s  0:00:00
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Using cached scipy-1.17.0-cp311-cp311-macosx_14_0_arm64.whl (20.1 MB)
# Installing collected packages: mpmath, farama-notifications, box2d, widgetsnbextension, urllib3, tqdm, sympy, PyYAML, python-dotenv, pyparsing, pygame, propcache, pillow, numpy, networkx, multidict, MarkupSafe, lightning-utilities, kiwisolver, jupyterlab_widgets, imageio_ffmpeg, idna, fsspec, frozenlist, fonttools, filelock, cycler, cloudpickle, charset_normalizer, certifi, attrs, aiohappyeyeballs, yarl, scipy, requests, proglog, pandas, opencv-python, jinja2, imageio, gymnasium, contourpy, ale_py, aiosignal, torch, moviepy, matplotlib, ipywidgets, aiohttp, torchmetrics, seaborn, pytorch-lightning, lightning, rldurham
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54/54 [rldurham]rldurham]lightning]ghtning]]
# Successfully installed MarkupSafe-3.0.3 PyYAML-6.0.3 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 ale_py-0.11.2 attrs-25.4.0 box2d-2.3.10 certifi-2026.1.4 charset_normalizer-3.4.4 cloudpickle-3.1.2 contourpy-1.3.3 cycler-0.12.1 farama-notifications-0.0.4 filelock-3.20.3 fonttools-4.61.1 frozenlist-1.8.0 fsspec-2026.1.0 gymnasium-1.2.3 idna-3.11 imageio-2.37.2 imageio_ffmpeg-0.6.0 ipywidgets-8.1.8 jinja2-3.1.6 jupyterlab_widgets-3.0.16 kiwisolver-1.4.9 lightning-2.6.0 lightning-utilities-0.15.2 matplotlib-3.10.8 moviepy-2.2.1 mpmath-1.3.0 multidict-6.7.1 networkx-3.6.1 numpy-2.4.1 opencv-python-4.13.0.90 pandas-3.0.0 pillow-11.3.0 proglog-0.1.12 propcache-0.4.1 pygame-2.6.1 pyparsing-3.3.2 python-dotenv-1.2.1 pytorch-lightning-2.6.0 requests-2.32.5 rldurham-0.1.1 scipy-1.17.0 seaborn-0.13.2 sympy-1.14.0 torch-2.10.0 torchmetrics-1.8.2 tqdm-4.67.1 urllib3-2.6.3 widgetsnbextension-4.0.15 yarl-1.22.0
# Collecting git+https://github.com/robert-lieck/rldurham.git@main
#   Cloning https://github.com/robert-lieck/rldurham.git (to revision main) to /private/var/folders/gr/j8nwj3f15hgg45p8gkw2c5b00000gn/T/pip-req-build-rh8pdqgy
#   Running command git clone --filter=blob:none --quiet https://github.com/robert-lieck/rldurham.git /private/var/folders/gr/j8nwj3f15hgg45p8gkw2c5b00000gn/T/pip-req-build-rh8pdqgy
#   Resolved https://github.com/robert-lieck/rldurham.git to commit a0b4c9257d3f41711e8ac3d391725e498568db4f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: IPython in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (9.9.0)
# Requirement already satisfied: ipywidgets in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (8.1.8)
# Requirement already satisfied: requests in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (2.32.5)
# Requirement already satisfied: gymnasium[Box2D,atari,other] in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (1.2.3)
# Requirement already satisfied: torch in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (2.10.0)
# Requirement already satisfied: numpy in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (2.4.1)
# Requirement already satisfied: scipy in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (1.17.0)
# Requirement already satisfied: pandas in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (3.0.0)
# Requirement already satisfied: lightning in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.1) (2.6.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ameliemajor/.local/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (0.11.2)
# Requirement already satisfied: box2d==2.3.10 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (2.6.1)
# Requirement already satisfied: swig==4.* in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (4.4.1)
# Requirement already satisfied: moviepy>=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (2.2.1)
# Requirement already satisfied: matplotlib>=3.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (3.10.8)
# Requirement already satisfied: opencv-python>=3.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (4.13.0.90)
# Requirement already satisfied: seaborn>=0.13 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.1) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (2.37.2)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (1.2.1)
# Requirement already satisfied: tqdm in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (4.67.1)
# Requirement already satisfied: six>=1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.1) (1.17.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.1) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->rldurham==0.1.1) (0.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jedi>=0.18.1->IPython->rldurham==0.1.1) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from pexpect>4.3->IPython->rldurham==0.1.1) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham==0.1.1) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham==0.1.1) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham==0.1.1) (0.2.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham==0.1.1) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham==0.1.1) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham==0.1.1) (3.0.16)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.1) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (2026.1.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.1) (0.15.2)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.1) (1.8.2)
# Requirement already satisfied: pytorch-lightning in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.1) (2.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (3.13.3)
# Requirement already satisfied: setuptools in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->rldurham==0.1.1) (80.9.0)
# Requirement already satisfied: filelock in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.1) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.1) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.1) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.1) (3.11)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from sympy>=1.13.3->torch->rldurham==0.1.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jinja2->torch->rldurham==0.1.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from requests->rldurham==0.1.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from requests->rldurham==0.1.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from requests->rldurham==0.1.1) (2026.1.4)
# Collecting git+https://github.com/robert-lieck/rldurham.git@dev
#   Cloning https://github.com/robert-lieck/rldurham.git (to revision dev) to /private/var/folders/gr/j8nwj3f15hgg45p8gkw2c5b00000gn/T/pip-req-build-zc8mp2_i
#   Running command git clone --filter=blob:none --quiet https://github.com/robert-lieck/rldurham.git /private/var/folders/gr/j8nwj3f15hgg45p8gkw2c5b00000gn/T/pip-req-build-zc8mp2_i
#   Running command git checkout -b dev --track origin/dev
#   Switched to a new branch 'dev'
#   branch 'dev' set up to track 'origin/dev'.
#   Resolved https://github.com/robert-lieck/rldurham.git to commit 321ebb566ac6d357031e7b218b1864571cbefa8e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: IPython in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (9.9.0)
# Requirement already satisfied: ipywidgets in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (8.1.8)
# Requirement already satisfied: requests in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (2.32.5)
# Requirement already satisfied: gymnasium[Box2D,atari,other] in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (1.2.3)
# Requirement already satisfied: torch in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (2.10.0)
# Requirement already satisfied: numpy in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (2.4.1)
# Requirement already satisfied: scipy in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (1.17.0)
# Requirement already satisfied: pandas in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (3.0.0)
# Requirement already satisfied: lightning in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from rldurham==0.1.0) (2.6.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ameliemajor/.local/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (0.11.2)
# Requirement already satisfied: box2d==2.3.10 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (2.6.1)
# Requirement already satisfied: swig==4.* in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (4.4.1)
# Requirement already satisfied: moviepy>=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (2.2.1)
# Requirement already satisfied: matplotlib>=3.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (3.10.8)
# Requirement already satisfied: opencv-python>=3.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (4.13.0.90)
# Requirement already satisfied: seaborn>=0.13 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from gymnasium[Box2D,atari,other]->rldurham==0.1.0) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (2.37.2)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (1.2.1)
# Requirement already satisfied: tqdm in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (4.67.1)
# Requirement already satisfied: six>=1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[Box2D,atari,other]->rldurham==0.1.0) (1.17.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from IPython->rldurham==0.1.0) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->rldurham==0.1.0) (0.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jedi>=0.18.1->IPython->rldurham==0.1.0) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from pexpect>4.3->IPython->rldurham==0.1.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham==0.1.0) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->rldurham==0.1.0) (0.2.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham==0.1.0) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham==0.1.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from ipywidgets->rldurham==0.1.0) (3.0.16)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.0) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (2026.1.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.0) (0.15.2)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.0) (1.8.2)
# Requirement already satisfied: pytorch-lightning in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning->rldurham==0.1.0) (2.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (3.13.3)
# Requirement already satisfied: setuptools in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->rldurham==0.1.0) (80.9.0)
# Requirement already satisfied: filelock in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.0) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from torch->rldurham==0.1.0) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->rldurham==0.1.0) (3.11)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from sympy>=1.13.3->torch->rldurham==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from jinja2->torch->rldurham==0.1.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from requests->rldurham==0.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from requests->rldurham==0.1.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages (from requests->rldurham==0.1.0) (2026.1.4)
# Building wheels for collected packages: rldurham
#   Building wheel for rldurham (pyproject.toml) ... done
#   Created wheel for rldurham: filename=rldurham-0.1.0-py3-none-any.whl size=29934 sha256=975bb88f50a627f75d0d55a8157cc724d6dd08c85e913ba698edec3d016fd828
#   Stored in directory: /private/var/folders/gr/j8nwj3f15hgg45p8gkw2c5b00000gn/T/pip-ephem-wheel-cache-q1by20a3/wheels/ad/cf/3e/8f521eb26988fed87a635ce635a87af809687339ade8f21ca3
# Successfully built rldurham
# Installing collected packages: rldurham
#   Attempting uninstall: rldurham
#     Found existing installation: rldurham 0.1.1
#     Uninstalling rldurham-0.1.1:
#       Successfully uninstalled rldurham-0.1.1
# Successfully installed rldurham-0.1.0

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""  # disable CUDA (better on Colab/NCC: choose an environment without GPU)

import gymnasium as gym
import rldurham as rld  # Reinforcement Learning Durham package with helper functions
# Out:
# /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages/rldurham/version_check.py:35: UserWarning: A newer version of rldurham is available (0.1.1). You have 0.1.0. Upgrade with:
#
#     pip install --upgrade rldurham
#
#   warnings.warn(

# %% [markdown]
# **Basic environment**

# %%
env = gym.make('CartPole-v1', render_mode="human")
observation, info = env.reset(seed=42)

for episode in range(10):
    observation, info = env.reset()
    done = False
    while not done:
        action = env.action_space.sample()  # random action
        observation, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated

env.close()
# Out:
# /Users/ameliemajor/miniforge3/envs/gymnasium/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# **Reinforcement Learning Durham:** _rldurham_ Python package

# %%
# drop-in for gym.make that enables logging (use render_mode="rgb_array" to enable video rendering)
env = rld.make('CartPole-v1', render_mode="rgb_array")

# record statistics (returned in info) and videos
env = rld.Recorder(
    env,
    smoothing=10,                       # track rolling averages (not required for coursework)
    video=True,                         # enable recording videos
    video_folder="videos",              # folder for videos
    video_prefix="xxxx00-agent-video",  # prefix for videos
    logs=True,                          # keep logs
)

# make reproducible by seeding everything (python, numpy, pytorch, env)
# this also calls env.reset
seed, observation, info = rld.seed_everything(42, env)

# optionally track statistics for plotting
tracker = rld.InfoTracker()

# run episodes
for episode in range(11):
    # recording statistics and video can be switched on and off (video recording is slow!)
    env.info = episode % 2 == 0   # track every other episode (usually tracking every episode is fine)
    env.video = episode % 4 == 0  # you only want to record videos every x episodes (set BEFORE calling reset!)
    #######################################################################
    # this is the same as above
    observation, info = env.reset()
    done = False
    while not done:
        action = env.action_space.sample()  # Random action
        observation, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
    #######################################################################
        if done:
            # per-episode statistics are returned by Recorder wrapper in info
            #     'idx': index/count of the episode
            #     'length': length of the episode
            #     'r_sum': sum of rewards in episode
            #     'r_mean': mean of rewards in episode
            #     'r_std': standard deviation of rewards in episode
            #     'length_': average `length' over smoothing window
            #     'r_sum_': reward sum over smoothing window (not the average)
            #     'r_mean_': average reward sum per episode over smoothing window (i.e. average of `r_sum')
            #     'r_std_': standard deviation of reward sum per episode over smoothing window

            # InfoTracker turns these into arrays over time
            tracker.track(info)
            print(tracker.info)

            # some plotting functionality is provided (this will refresh in notebooks)
            #  - combinations of ``r_mean`` and ``r_std`` or ``r_mean_`` and ``r_std_`` are most insightful
            #  - for `CartPole`, ``length`` and ``r_sum`` are the same as there is a unit reward for each
            #    time step of successful balancing
            tracker.plot(r_mean_=True, r_std_=True,
                         length=dict(linestyle='--', marker='o'),
                         r_sum=dict(linestyle='', marker='x'))

# don't forget to close environment (e.g. triggers last video save)
env.close()

# write log file (for coursework)
env.write_log(folder="logs", file="xxxx00-agent-log.txt")

# %%
# print log file
import pandas as pd
log_file = "logs/xxxx00-agent-log.txt"
print(f"log file: {log_file}")
print(pd.read_csv(log_file, sep="\t").head())

# %%
# show video
import os, re
from ipywidgets import Video
video_file = "videos/" + sorted(f for f in os.listdir("videos") if re.match(r".+episode=4.+\.mp4", f))[0]
print(f"video file: {video_file}")
Video.from_file(video_file)

# %% [markdown]
# **Different environments**

# %%
## render mode
# rm = 'human'     # for rendering in separate window
rm = 'rgb_array' # for recording videos or rendering in notebook
# rm = None        # no rendering

## select environment
env = rld.make('CartPole-v1', render_mode=rm)              # easy discrete
# env = rld.make('FrozenLake-v1', render_mode=rm)            # easy discrete
# env = rld.make('LunarLander-v3', render_mode=rm)           # discrete
# env = rld.make('ALE/Breakout-v5', render_mode=rm)          # discrete (atari)
# env = rld.make('Pong-ram-v4', render_mode=rm)              # discrete (atari)
# env = rld.make('Gravitar-ram-v4', render_mode=rm)          # hard discrete (atari)
#
# env = rld.make('Pendulum-v1', render_mode=rm)              # easy continuous
# env = rld.make('LunarLanderContinuous-v3', render_mode=rm) # continuous
# env = rld.make('BipedalWalker-v3', render_mode=rm)         # continuous
# env = rld.make('BipedalWalkerHardcore-v3', render_mode=rm) # hard continuous

## wrap for stats and video recording (requires render_mode='rgb_array')
# env = rld.Recorder(env, video=True)
# env.video = False  # deactivate

## there are many more!
# gym.pprint_registry()

# get some info
discrete_act = hasattr(env.action_space, 'n')
discrete_obs = hasattr(env.observation_space, 'n')
act_dim = env.action_space.n if discrete_act else env.action_space.shape[0]
obs_dim = env.observation_space.n if discrete_obs else env.observation_space.shape[0]
discrete_act, discrete_obs, act_dim, obs_dim = rld.env_info(env)  # same
print(f"The environment has "
      f"{act_dim}{(f' discrete' if discrete_act else f'-dimensional continuous')} actions and "
      f"{obs_dim}{(f' discrete' if discrete_obs else f'-dimensional continuous')} observations.")
print('The maximum timesteps is: {}'.format(env.spec.max_episode_steps))

print("\nrldurham helper function:")
rld.env_info(env, print_out=True)

# %%
for episode in range(1):
    observation, info = env.reset()
    if env.render_mode == 'rgb_array':
        rld.render(env, clear=True)
    done = False
    for step in range(200):
        action = env.action_space.sample()  # random action
        observation, reward, terminated, truncated, info = env.step(action)
        if env.render_mode == 'rgb_array':
            rld.render(env, clear=True)
        done = terminated or truncated
        if done:
            break
env.close()

# %% [markdown]
# **Training an agent**

# %%
import numpy as np
import torch

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('The device is: {}'.format(device))
if device.type != 'cpu': print('It\'s recommended to train on the cpu for this')

print('\nrldurham helper function:')
rld.check_device()

# %%
class Agent(torch.nn.Module):
    def __init__(self, env):
        super().__init__()
        self.discrete_act, self.discrete_obs, self.act_dim, self.obs_dim = rld.env_info(env)

    def prob_action(self, obs):
        return np.ones(self.act_dim)/self.act_dim

    def sample_action(self, prob):
        if self.discrete_act:
            return np.random.choice(self.act_dim, p=prob)
        else:
            return np.random.uniform(-1.0, 1.0, size=self.act_dim)

    def train(self):
        return

    def put_data(self, item):
        return

# %%
# init environment
env = rld.make('CartPole-v1')
env = rld.Recorder(env, smoothing=10)

# seed
rld.seed_everything(seed=42, env=env)

# init agent
agent = Agent(env)

# training procedure
tracker = rld.InfoTracker()
for episode in range(201):
    obs, info = env.reset()
    done = False

    # get episode
    while not done:
        # select action
        prob = agent.prob_action(obs)
        action = agent.sample_action(prob)

        # take action in environment
        next_obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        agent.put_data((reward, prob[action] if agent.discrete_act else None))
        obs = next_obs

    # track and plot
    tracker.track(info)
    if episode % 10 == 0:
        tracker.plot(r_mean_=True, r_std_=True)

    # update agent's policy
    agent.train()
env.close()

# %% [markdown]
# **REINFORCE agent example**
# This code is based on: https://github.com/seungeunrho/minimalRL
#
# Note: these implementations are good to study, although most are for discrete action spaces

# %%
# this is an implementation of REINFORCE (taught in lecture 8) - one of the simplest classical policy gradient methods
# this will only work for simple discrete control problems like cart pole or (slowly) lunar lander discrete
plot_interval = 50
video_every = 500
max_episodes = 5000


class Agent(torch.nn.Module):
    def __init__(self, env):
        super().__init__()
        discrete_act, discrete_obs, act_dim, obs_dim = rld.env_info(env)
        if not discrete_act:
            raise RuntimeError("REINFORCE only works for discrete action spaces")
        self.data = []
        self.fc1 = torch.nn.Linear(obs_dim, 128)
        self.fc2 = torch.nn.Linear(128, act_dim)
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.0002)

    def sample_action(self, prob):
        m = torch.Categorical(prob)
        a = m.sample()
        return a.item()

    def prob_action(self, s):
        x = torch.F.relu(self.fc1(torch.from_numpy(s).float()))
        return torch.F.softmax(self.fc2(x), dim=0)

    def put_data(self, item):
        self.data.append(item)

    def train(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + 0.98 * R
            loss = -torch.log(prob) * R
            loss.backward()
        self.optimizer.step()
        self.data = []

# %% [markdown]
# **Custom environments (here: multi-armed bandits)**

# %%
# one armed bandits are slot machines where you can win or loose money
# some casinos tune them, so some machines are less successful (the probability distribution of winning)
# the machines also dish out varying rewards (the reward distribution)
# so basically each machine has some probability of dishing out £ reward (p_dist doesn't need to sum to 1) else it gives £0

class BanditEnv(gym.Env):

    def __init__(self, p_dist=[0.4,0.2,0.1,0.1,0.1,0.7], r_dist=[1,0.1,2,0.5,6,70]):

        self.p_dist = p_dist
        self.r_dist = r_dist

        self.n_bandits = len(p_dist)
        self.action_space = gym.spaces.Discrete(self.n_bandits)
        self.observation_space = gym.spaces.Discrete(1)

    def step(self, action):
        assert self.action_space.contains(action)

        reward = -25
        terminated = True
        truncated = False

        if np.random.uniform() < self.p_dist[action]:
            if not isinstance(self.r_dist[action], list):
                reward += self.r_dist[action]
            else:
                reward += np.random.normal(self.r_dist[action][0], self.r_dist[action][1])

        return np.zeros(1), reward, terminated, truncated, {}

    def reset(self, seed=None, options=None):
        if seed is not None:
            self.np_random, seed = gym.utils.seeding.np_random(seed)
        return np.zeros(1), {}

    def render(self):
        pass

# %%
# initialise
discrete = True
env = BanditEnv()
obs_dim = 1
act_dim = len(env.p_dist)
env.spec = gym.envs.registration.EnvSpec('BanditEnv-v0', max_episode_steps=5)
max_episodes = 1000

for episode in range(10):
    observation, info = env.reset()
    done = False
    while not done:
        action = env.action_space.sample()  # random action
        observation, reward, terminated, truncated, info = env.step(action)
        print(action, reward)
        done = terminated or truncated

env.close()

# %%
gym.register(id="BanditEnv-v0", entry_point=BanditEnv)
gym.pprint_registry()
